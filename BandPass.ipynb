# %%
import utils as utl
import bp_template as bp


Gp = 0.95
Ga = 0.005
wp1 = 30000
wp2 = 60000
wa1 = 5000
wa2 = 100000

hp_template = bp.BPTemplate(Gp, Ga, wp1, wp2, wa1, wa2)
hp_template.set_approximation_function(bp.tmp.ApproximationFunction.Ch2)
hp_template.generate_final_tf()
utl.print_bode(hp_template.final_function, -1,11, 1000000)
utl.print_pzm(hp_template.final_function)
# Out:
# 'Poles:'
# '1) Wo:66098.98199665571, Phase:1.725616081280815, Q:3.2424998420410036'
# '2) Wo:66098.98199665571, Phase:-1.725616081280815, Q:3.2424998420410067'
# '3) Wo:53966.84884060977, Phase:2.046867028768567, Q:1.0910114024142183'
# '4) Wo:53966.84884060977, Phase:-2.046867028768567, Q:1.0910114024142186'
# '5) Wo:33353.80958255105, Phase:2.0468670287685664, Q:1.0910114024142195'
# '6) Wo:33353.80958255105, Phase:-2.0468670287685664, Q:1.0910114024142197'
# '7) Wo:27231.886870679202, Phase:1.7256160812808128, Q:3.24249984204105'
# '8) Wo:27231.886870679202, Phase:-1.7256160812808128, Q:3.242499842041053'
# 'Zeros:'
# '1) Wo:255297.55948693113, Phase:1.5707963379178334'
# '2) Wo:255297.55948693113, Phase:-1.5707963379178334'
# '3) Wo:118072.17208474637, Phase:1.5707963446267599'
# '4) Wo:118072.17208474637, Phase:-1.5707963446267599'
# '5) Wo:15244.913074928916, Phase:1.5707963446267599'
# '6) Wo:15244.913074928916, Phase:-1.5707963446267599'
# '7) Wo:7050.596189080082, Phase:1.5707963379178334'
# '8) Wo:7050.596189080082, Phase:-1.5707963379178334'
